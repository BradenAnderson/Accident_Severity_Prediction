# %% [markdown]
# # Team Introduction
# Our group is comprised of Braden Anderson, Hien Lam, and Tavin Weeda.

# %% [markdown]
# # Business Understanding
# Describe the purpose of the data set you selected (i.e., why was this data collected in the first place?). Describe how you would define and measure the outcomes from the dataset. That is, why is this data important and how do you know if you have mined useful knowledge from the dataset? How would you measure the effectiveness of a good prediction algorithm? Be specific.
#
# Crash Report Sampling System (CRSS) is a probability sample of police-reported traffic crashes used to analyze crash trends and promote highway safety measures as well as public information initiatives. The 2020 data encompassing driver-related, vehicular accidents was obtained. First, we seek to predict injury severity of the crash. This is a classification technique in which effectiveness will be measured with accuracy, recall, F1 score, and ROC AUC in conjunction with 10-fold cross validation. Afterwards, we will conduct regression to predict age of driver and obtain its mean squared error, root mean squared error, and mean absolute percentage error in conjunction with 10-fold cross validation. Our goal is to elucidate factors that contribute to crashes as they relate to the driver, vehicle, road infrastructure, and environment in order to effectively reduce/prevent accidents.

# %% [markdown]
# # Data Meaning Type
# Describe the meaning and type of data (scale, values, etc.) for each attribute in the data file.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from dfply import *
from data_cleaning import *

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/lam-hien/MSDS-Projects/main/Crash%20Severity%20Prediction/Data.csv')
df = pd.read_csv("./dataset_revs/Merged_File_05092022.csv")

# %%
# Function to clean the data
df = clean_data(dataframe=df)

# %%
# Select relevant columns for EDA where values are descriptive (not numerical indicators)
eda_df = df >> select(X.regionname, X.urbanicityname, X.makename, X.body_typname, X.mod_yearname, X.vtrafwayname, 
                      X.vnum_lanname, X.vsurcondname, X.vtrafconname, X.typ_intname, X.wrk_zonename, X.int_hwyname, 
                      X.weathername, X.wkdy_imname, X.hour_imname, X.reljct2_imname, X.lgtcon_imname, X.maxsev_imname, 
                      X.alchl_imname, X.age_im, X.sex_imname, X.vspd_lim, X.trav_sp, X.hour_binned, X.speeding_status)

# %%
print(eda_df.shape)
print(eda_df.info())
# Out:
# (48227, 25)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48227 entries, 0 to 48463
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   regionname       48227 non-null  object
#  1   urbanicityname   48227 non-null  object
#  2   makename         48227 non-null  object
#  3   body_typname     48227 non-null  object
#  4   mod_yearname     48227 non-null  object
#  5   vtrafwayname     48227 non-null  object
#  6   vnum_lanname     48227 non-null  object
#  7   vsurcondname     48227 non-null  object
#  8   vtrafconname     48227 non-null  object
#  9   typ_intname      48227 non-null  object
#  10  wrk_zonename     48227 non-null  object
#  11  int_hwyname      48227 non-null  object
#  12  weathername      48227 non-null  object
#  13  wkdy_imname      48227 non-null  object
#  14  hour_imname      48227 non-null  object
#  15  reljct2_imname   48227 non-null  object
#  16  lgtcon_imname    48227 non-null  object
#  17  maxsev_imname    48227 non-null  object
#  18  alchl_imname     48227 non-null  object
#  19  age_im           48227 non-null  float64
#  20  sex_imname       48227 non-null  object
#  21  vspd_lim         48227 non-null  int64
#  22  trav_sp          48227 non-null  int64
#  23  hour_binned      48227 non-null  object
#  24  speeding_status  48227 non-null  object
# dtypes: float64(1), int64(2), object(22)
# memory usage: 9.6+ MB
# None

# %%
eda_df.head()
# Out:
#   regionname urbanicityname makename  \
# 0       West          Rural   Toyota
# 1      South          Urban      BMW
# 2       West          Rural   Subaru
# 3  Northeast          Rural   Subaru
# 4    Midwest          Rural     Ford
#
#                                         body_typname mod_yearname  \
# 0                              4-door sedan, hardtop         2018
# 1                              4-door sedan, hardtop         2013
# 2  Compact Utility (Utility Vehicle Categories "S...         2015
# 3      Station Wagon (excluding van and truck based)         2004
# 4                                       Light Pickup         2003
#
#                                   vtrafwayname  vnum_lanname vsurcondname  \
# 0                         Two-Way, Not Divided    Five lanes         Snow
# 1                         Two-Way, Not Divided     Two lanes          Dry
# 2  Two-Way,  Divided, Positive  Median Barrier     Two lanes         Snow
# 3                                 Not Reported  Not Reported         Snow
# 4                                 Not Reported  Not Reported          Dry
#
#                                         vtrafconname            typ_intname  \
# 0  Traffic control signal(on colors) not known wh...  Four-Way Intersection
# 1                                        No Controls    Not an Intersection
# 2                                        No Controls    Not an Intersection
# 3                                       Warning Sign    Not an Intersection
# 4                                        No Controls    Not an Intersection
#
#    ...                          reljct2_imname       lgtcon_imname  \
# 0  ...                            Intersection            Daylight
# 1  ...                            Non-Junction  Dark - Not Lighted
# 2  ...  Other location within Interchange Area            Daylight
# 3  ...                            Non-Junction  Dark - Not Lighted
# 4  ...                            Non-Junction  Dark - Not Lighted
#
#         maxsev_imname         alchl_imname age_im sex_imname vspd_lim trav_sp  \
# 0  No Apparent Injury  No Alcohol Involved   61.0     Female       98      25
# 1     Possible Injury  No Alcohol Involved   23.0       Male       25      45
# 2  No Apparent Injury  No Alcohol Involved   20.0       Male       80      65
# 3  No Apparent Injury  No Alcohol Involved   23.0       Male       50     998
# 4     Possible Injury  No Alcohol Involved   57.0     Female       55     998
#
#   hour_binned  speeding_status
# 0     Morning          unknown
# 1       Night         speeding
# 2   Afternoon     not speeding
# 3     Evening          unknown
# 4     Evening          unknown
#
# [5 rows x 25 columns]

# %%
data = [
    ['regionname', 'categorical', 'where crash occurred', '4: Northeast (PA, NJ, NY, NH, VT, RI, MA, ME, CT), West (MT, ID, WA, OR, CA, NV, NM, AZ, UT, CO, WY, AK, HI), Midwest (OH, IN, IL, MI, WI, MN, ND, SD, NE, IA, MO, KS), South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA, FL, AL, MS, LA, AR, OK, TX)'],
    ['urbanicityname', 'categorical', 'geographical area of the crash', '2: urban (population >= 250k), rural (population < 250k)'],
    ['makename', 'categorical', 'manufacturer of vehicle', '64: Ford, Chevrolet, Honda, Toyta, Nissan'],
    ['body_typname', 'categorical', 'vehicle classification based on its body configuration, size, shape, doors', '56: 4-door sedan, compact, pickup, stationwagon, van, motorcycle, etc.'],
    ['mod_yearname', 'integer', 'vehicle model year', 'Exists as object in raw data due to unreported/unknown strings however we will clean and convert to int.'],
    ['vtrafwayname', 'categorical', 'trafficway flow just prior to crash', '9: Two-Way Not Divided, Not Reported, Two-Way Divided Positive Median Barrier, Two-Way Divided Unprotected Median, Two-Way Not Divided With a Continuous Left-Turn Lane, Non-Trafficway or Driveway Access, Entrance/Exit Ramp, One-Way Trafficway, Reported as Unknown'],
    ['vnum_lanname', 'categorical', 'number of travel lanes just prior to crash. Median: lanes in opposite directions are additive. No median: lanes in traveling direction counts', '10: Two lanes, Not Reported, Three lanes, Four lanes, Five lanes, Non-Trafficway or Driveway Access, Six lanes, One lane, Seven or more lanes, Reported as Unknown   '],
    ['vsurcondname', 'categorical', 'roadway surface condition just prior to crash', '13: Dry, wet, not reported, non-trafficway or driveway access, snow, ice/frost, water standing or moving, slush, mud dirt gravel, reported as unknown, sand, other, oil'],
    ['vtrafconname', 'categorical', 'traffic controls in the vehicle’s environment just prior to crash', '19: Traffic control signal, stop sign, yield sign, warning sign, person, school zone, etc'],
    ['typ_intname', 'categorical', 'type of intersection just prior to crash', '11: Not an Intersection, Four-Way Intersection, T-Intersection, Not Reported, Y-Intersection, Five Point or More,Roundabout, Traffic Circle, L-Intersection, Other Intersection Type, Reported as Unknown'],
    ['wrk_zonename', 'categorical', 'whether crash occurred within boundaries of work zone', '5: None, construction, work zone (type unknown), maintenance, utility'],
    ['int_hwyname', 'categorical', 'whether crash occurred on interstate highway', '3: yes, no, unknown'],
    ['weathername', 'categorical', 'prevailing atmospheric conditions at the time of the crash', '13: Clear, Cloudy, Rain, Not Reported, Snow, Fog, Smog, Smoke, Severe Crosswinds, Reported as Unknown, Blowing Snow, Sleet or Hail, Freezing Rain or Drizzle, Other, Blowing Sand, Soil, Dirt'],
    ['wkdy_imname', 'categorical', 'day of week at time of the crash', '7: one for each day of the week'],
    ['hour_imname', 'categorical', 'hour at which crash occurred', '24: one for each hour in a day'],
    ['hour_binned', 'categorical', 'hours binned', '4: morning (6am-noon), afternoon (noon-6pm), evening (6pm-midnight), night (midnight-6am)'],
    ['reljct2_imname', 'categorical', "crash's location with respect to presence in or proximity to junction or interchange areas", '13: Non-Junction, Intersection, Intersection-Related, Driveway Access Related, Through Roadway, Entrance/Exit Ramp Related, Driveway Access, Other location within Interchange Area, Entrance/Exit Ramp, Crossover-Related, Acceleration/Deceleration Lane, Railway Grade Crossing, Shared-Use Path Crossing'],
    ['lgtcon_imname', 'categorical', 'type/level of light at time of crash', '7: Daylight, Dark (lighted), Dark (not lighted), Dusk, Dawn, Dark (unknown lighting), Other'],
    ['alchl_imname', 'categorical', "driver's alcohol use", '2: alcohol involved, no alcohol involved'],
    ['age_im', 'integer', "driver's age at time of crash, in years, with respect to their last birthday", '-'],
    ['sex_imname', 'categorical', 'sex of driver', '2: male, female'],
    ['vspd_lim', 'integer', 'speed limit in mph', '-'],
    ['trav_sp', 'integer', 'speed of the vehicle prior to crash occurrence as reported by the officer', '-'],
    ['speeding_status', 'categorical', 'driver behavior relative to speed', '3: speeding, not speeding, unknown'],
    ['maxsev_imname', 'categorical', 'severity of injury sustained by the driver', '4: No apparent injury, possible injury, suspected serious injury, fatal injury']
]
datadesc = pd.DataFrame(data, columns=['Feature Name', 'Datatype', 'Description', 'Levels, if applicable'])
pd.set_option('max_colwidth',300)

print('This dataset consisted of 48227 rows and 25 columns. Relevant information for each attribute is as follows:')
datadesc
# Out:
# This dataset consisted of 48227 rows and 25 columns. Relevant information for each attribute is as follows:
#        Feature Name     Datatype  \
# 0        regionname  categorical
# 1    urbanicityname  categorical
# 2          makename  categorical
# 3      body_typname  categorical
# 4      mod_yearname      integer
# 5      vtrafwayname  categorical
# 6      vnum_lanname  categorical
# 7      vsurcondname  categorical
# 8      vtrafconname  categorical
# 9       typ_intname  categorical
# 10     wrk_zonename  categorical
# 11      int_hwyname  categorical
# 12      weathername  categorical
# 13      wkdy_imname  categorical
# 14      hour_imname  categorical
# 15      hour_binned  categorical
# 16   reljct2_imname  categorical
# 17    lgtcon_imname  categorical
# 18     alchl_imname  categorical
# 19           age_im      integer
# 20       sex_imname  categorical
# 21         vspd_lim      integer
# 22          trav_sp      integer
# 23  speeding_status  categorical
# 24    maxsev_imname  categorical
#
#                                                                                                                                       Description  \
# 0                                                                                                                            where crash occurred
# 1                                                                                                                  geographical area of the crash
# 2                                                                                                                         manufacturer of vehicle
# 3                                                                      vehicle classification based on its body configuration, size, shape, doors
# 4                                                                                                                              vehicle model year
# 5                                                                                                             trafficway flow just prior to crash
# 6   number of travel lanes just prior to crash. Median: lanes in opposite directions are additive. No median: lanes in traveling direction counts
# 7                                                                                                   roadway surface condition just prior to crash
# 8                                                                               traffic controls in the vehicle’s environment just prior to crash
# 9                                                                                                        type of intersection just prior to crash
# 10                                                                                          whether crash occurred within boundaries of work zone
# 11                                                                                                   whether crash occurred on interstate highway
# 12                                                                                     prevailing atmospheric conditions at the time of the crash
# 13                                                                                                               day of week at time of the crash
# 14                                                                                                                   hour at which crash occurred
# 15                                                                                                                                   hours binned
# 16                                                     crash's location with respect to presence in or proximity to junction or interchange areas
# 17                                                                                                           type/level of light at time of crash
# 18                                                                                                                           driver's alcohol use
# 19                                                                   driver's age at time of crash, in years, with respect to their last birthday
# 20                                                                                                                                  sex of driver
# 21                                                                                                                             speed limit in mph
# 22                                                                      speed of the vehicle prior to crash occurrence as reported by the officer
# 23                                                                                                              driver behavior relative to speed
# 24                                                                                                     severity of injury sustained by the driver
#
#                                                                                                                                                                                                                                                                                           Levels, if applicable
# 0                                                            4: Northeast (PA, NJ, NY, NH, VT, RI, MA, ME, CT), West (MT, ID, WA, OR, CA, NV, NM, AZ, UT, CO, WY, AK, HI), Midwest (OH, IN, IL, MI, WI, MN, ND, SD, NE, IA, MO, KS), South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA, FL, AL, MS, LA, AR, OK, TX)
# 1                                                                                                                                                                                                                                                      2: urban (population >= 250k), rural (population < 250k)
# 2                                                                                                                                                                                                                                                                     64: Ford, Chevrolet, Honda, Toyta, Nissan
# 3                                                                                                                                                                                                                                        56: 4-door sedan, compact, pickup, stationwagon, van, motorcycle, etc.
# 4                                                                                                                                                                                                      Exists as object in raw data due to unreported/unknown strings however we will clean and convert to int.
# 5                                       9: Two-Way Not Divided, Not Reported, Two-Way Divided Positive Median Barrier, Two-Way Divided Unprotected Median, Two-Way Not Divided With a Continuous Left-Turn Lane, Non-Trafficway or Driveway Access, Entrance/Exit Ramp, One-Way Trafficway, Reported as Unknown
# 6                                                                                                                                         10: Two lanes, Not Reported, Three lanes, Four lanes, Five lanes, Non-Trafficway or Driveway Access, Six lanes, One lane, Seven or more lanes, Reported as Unknown
# 7                                                                                                                                       13: Dry, wet, not reported, non-trafficway or driveway access, snow, ice/frost, water standing or moving, slush, mud dirt gravel, reported as unknown, sand, other, oil
# 8                                                                                                                                                                                                                     19: Traffic control signal, stop sign, yield sign, warning sign, person, school zone, etc
# 9                                                                                                     11: Not an Intersection, Four-Way Intersection, T-Intersection, Not Reported, Y-Intersection, Five Point or More,Roundabout, Traffic Circle, L-Intersection, Other Intersection Type, Reported as Unknown
# 10                                                                                                                                                                                                                                        5: None, construction, work zone (type unknown), maintenance, utility
# 11                                                                                                                                                                                                                                                                                          3: yes, no, unknown
# 12                                                                                                                13: Clear, Cloudy, Rain, Not Reported, Snow, Fog, Smog, Smoke, Severe Crosswinds, Reported as Unknown, Blowing Snow, Sleet or Hail, Freezing Rain or Drizzle, Other, Blowing Sand, Soil, Dirt
# 13                                                                                                                                                                                                                                                                              7: one for each day of the week
# 14                                                                                                                                                                                                                                                                               24: one for each hour in a day
# 15                                                                                                                                                                                                                    4: morning (6am-noon), afternoon (noon-6pm), evening (6pm-midnight), night (midnight-6am)
# 16  13: Non-Junction, Intersection, Intersection-Related, Driveway Access Related, Through Roadway, Entrance/Exit Ramp Related, Driveway Access, Other location within Interchange Area, Entrance/Exit Ramp, Crossover-Related, Acceleration/Deceleration Lane, Railway Grade Crossing, Shared-Use Path Cros...
# 17                                                                                                                                                                                                                  7: Daylight, Dark (lighted), Dark (not lighted), Dusk, Dawn, Dark (unknown lighting), Other
# 18                                                                                                                                                                                                                                                                     2: alcohol involved, no alcohol involved
# 19                                                                                                                                                                                                                                                                                                            -
# 20                                                                                                                                                                                                                                                                                              2: male, female
# 21                                                                                                                                                                                                                                                                                                            -
# 22                                                                                                                                                                                                                                                                                                            -
# 23                                                                                                                                                                                                                                                                           3: speeding, not speeding, unknown
# 24                                                                                                                                                                                                                               4: No apparent injury, possible injury, suspected serious injury, fatal injury

# %% [markdown]
# # Data Quality
# Verify data quality: Explain any missing values, duplicate data, and outliers. Are those mistakes? How do you deal with these problems? Give justifications for your methods.
#
# Each observation corresponded to a driver from a unique accident, as noted under `casenum` thus duplicate data was a nonissue. Due to the reliance of information contained in police reports, missing values were present with the unreported or unknown designation. The most concerning features were `trav_sp` (traveling vehicle speed) and `vspd_lim` (reported speed limit). We simply plotted the raw values for EDA but will one-hot encode them going forward to keep the full data. The other features had very few unknown/unreported values (less than 1% of the data per variable) and were removed. Most of the outliers encountered were scant distributed among both extremes of categorical levels. We dealt with this by binning similar levels together to ensure the integrity of the data or removed them if they were not representative of our population. For example, age of cars 50+ were binned together and drivers below 16 years of age were removed.

# %%
# There are zero na values because the data will designate "unknown" or "unreported" instead.
na_vals = eda_df.isnull().sum()
na_vals[na_vals > 0]
# Out:
# Series([], dtype: int64)

# %%
# Verify that there are not any duplicate case numbers in the dataset.
df['casenum'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Simple Statistics
# Visualize appropriate statistics (e.g., range, mode, mean, median, variance, counts) for a subset of attributes. Describe anything meaningful you found from this or if you found something potentially interesting. Note: You can also use data from other sources for comparison. Explain why the statistics run are meaningful.

# %% [markdown]
# ## Quantitative Variables
# We've filtered the data to drivers age 16 and above, vehicles age 30 or less, and traveling speed 150 mph or below. The average statistics is a driver approximately 40 years of age with an 11 year old car driving at 30 mph at reported speed limit of 42 mph. The median age of the driver is 35 years old with an IQR of 27 years. The median values of vehicle age, traveling speed, and speed limit did not veer (pun intended) from the mean and their respective IQR are 11 years, 35 mph, and 20 mph. The driving speed is surprisingly low (well below the speed limit) and is potentially pulled down from many 0 mph observations; we will investigate this further prior to modeling. Similarly, driver age will require binning at the upper range.

# %%
# Create new df to grab summary statistics for quantitative variables
quant_var = pd.DataFrame(eda_df)

# New vehicle year column
quant_var["vehicle_year"] = quant_var["mod_yearname"]

# Numeric Placeholder for unknown and not reported, using 2025
quant_var.loc[quant_var["vehicle_year"].isin(["Unknown", "Not Reported"]), "vehicle_year"] = 2025

# Cast the new yr to int
quant_var["vehicle_year"] = quant_var["vehicle_year"].astype(int)

# Calculate age of vehicle
quant_var['vehicle_age'] = 2022 - quant_var['vehicle_year']

# Filtered driver's age to 16+, driver's speed to below 150 mph, and vehicle age to 30 or less
quant_var = quant_var >> select(X.age_im, X.vehicle_age, X.trav_sp, X.vspd_lim) >> filter_by(X.age_im >15, X.trav_sp < 151, X.vehicle_age < 31, X.vehicle_age > 0, X.vspd_lim < 98)

# %%
quant_var.describe()

# %% [markdown]
# ## Categorical Variables
# Distribution of the predictor, injury severity, is as follows: no apparent injury (44%), possible injury (41%), suspected injury (12%), and fatal injury (3%). Listed below are the prevailing level of each feature just prior to the crash.

# %%
sns.catplot(data = eda_df,
            x='maxsev_imname', 
            kind="count", 
            order=['No Apparent Injury','Possible Injury','Suspected Serious Injury', 'Fatal Injury'], 
            height=5, 
            aspect=3, 
            palette='husl').set_xticklabels(rotation=40).set_yticklabels(rotation=40);
plt.xlabel('Injury Severity', size=20, weight=1000)
plt.ylabel('Count', size=20, weight=1000)
plt.title("Proportion of Injury Severity", size=20);

# %%
# Descriptive statistics for the categorical attributes
eda_df.describe(include=[object], exclude=[np.number]).T
# Out:
#                  count unique                    top   freq
# regionname       48227      4                  South  25379
# urbanicityname   48227      2                  Urban  35443
# makename         48227     64                   Ford   6424
# body_typname     48227     56  4-door sedan, hardtop  16844
# mod_yearname     48227     67                   2016   3660
# vtrafwayname     48227      9   Two-Way, Not Divided  20386
# vnum_lanname     48227     10              Two lanes  17083
# vsurcondname     48227     13                    Dry  35982
# vtrafconname     48227     19            No Controls  24395
# typ_intname      48227     11    Not an Intersection  26721
# wrk_zonename     48227      5                   None  47332
# int_hwyname      48227      3                     No  43748
# weathername      48227     13                  Clear  33651
# wkdy_imname      48227      7                 Friday   8035
# hour_imname      48227     24          5:00pm-5:59pm   4144
# reljct2_imname   48227     13           Non-Junction  20702
# lgtcon_imname    48227      7               Daylight  32840
# maxsev_imname    48227      4     No Apparent Injury  21211
# alchl_imname     48227      2    No Alcohol Involved  44650
# sex_imname       48227      2                   Male  29802
# hour_binned      48227      4                Evening  15860
# speeding_status  48227      3                unknown  28592

# %% [markdown]
# # Visualize Attributes
# Visualize the most interesting attributes (at least 5 attributes, your opinion on what is interesting). Important: Interpret the implications for each visualization. Explain for each attribute why the chosen visualization is appropriate.

# %% [markdown]
# ## Age of driver
#
# Driver's age is a continuous variable thus a histogram is an appropriate plot to represent the number of observations at each "bin". The density curve is overlayed to give the audience a better visual of the distribution. The age of driver is right skewed with a peak at 20 years old. This tracks with what we know that less experienced drivers tend to engage in more accidents. The distribution slowly decreases with a more drastic decline at high 30s and high 60s. We surmise the former could be attributed to less observations in the data and the latter is due to retirement age so they are on the road less. Looking ahead to modeling, we will have to bin the upper age bracket on account of smaller sample size.

# %%
# Data clean AGE: 
## Youngest driver is 5 years old and 180 obs where driver is below 16 years. Remove as those ages are clearly outliers or not representative of population
## Oldest driver is 101 and 984 obs where driver is 80+ years. Keep for EDA but will bin for modeling
print(f"Youngest driver: {eda_df['age_im'].min()} yrs, Number of drivers younger than 16 yrs: {len(eda_df >> mask(X.age_im < 16))}")
print(f"Oldest driver: {eda_df['age_im'].max()} yrs, Number of drivers 80+ yrs: {len(eda_df >> mask(X.age_im > 79))}")
age = eda_df >> filter_by(X.age_im >= 15)
# Out:
# Youngest driver: 5.0 yrs, Number of drivers younger than 16 yrs: 180
# Oldest driver: 101.0 yrs, Number of drivers 80+ yrs: 984

# %%
plt.figure(figsize = (15,8));
sns.histplot(age, x = "age_im", bins=30,  stat="density", color ='lightcoral');
sns.kdeplot(data=age, x = "age_im");
plt.xlabel('Age', weight = 1000, size=20)
plt.ylabel('Density', weight = 1000, size=20)
plt.title("Distribution of Driver's Age", size=20);

# %% [markdown]
# ## Age of vehicle
# While the function of cars over the years has arguably been left unchanged, their construction materials and features have undergone transformations.  From “tough” to “crumple” steel alloys and aluminum bodies, ‘locking’ to anti-lock to self-activating breaking, companies are adding more safety features and learning from past builds every year.  From this perspective, we have assumed this feature will play a substantial role in our model building.
#
# We were given the year of each car and converted it to an age; the year ‘2022’ represented by an age of ‘0’.  Using the same principles of graphing as we did with ‘Driver’s Age’, the initial histogram shows a right-skewed bimodal distribution with the major peak at an age of 6 years old and minor peak at 14 years old.  Cars prior to 1980 represented only 67 observations and will be altered before modelling. The distribution makes intuitive sense as there is a limited supply of cars in each year; there are less older cars which would imply less older cars in accidents.
#
# After some thought, we noticed the smaller peak coincided right before the Great Recession in 2008 which hit the automotive industry particularly hard.  The lack of vehicles with an age of 7-13 year in accidents might be reflective of the lack of production during the years following the recession.  However, we are here to investigate the distribution, so we will not dwell on the cause for too long.  As we model, it will be interesting to see if the convexity in the graph plays a role.

# %%
# Removing unknown and not reported for plotting, these will be imputed for the analysis
dft = df.loc[~df["mod_yearname"].isin(["Unknown", "Not Reported"]), :].copy(deep=True)

# Calculate vehicle age
dft["vehicle_age"] = 2022 - dft["mod_yearname"].astype(int) 

# Set up figure and axis
fig, ax = plt.subplots(figsize = (15,8))

# Add histogram and density curve
sns.histplot(x = "vehicle_age", data=dft, binwidth=1,  stat="density", ax=ax);
sns.kdeplot(data=dft, x = "vehicle_age", color ='lightcoral');

# Adjust tick parameters and add plot labels
ax.tick_params(axis='both', labelsize=12)
plt.xlabel('Vehicle Age', weight = 1000, size=20)
plt.ylabel('Density', weight = 1000, size=20)
plt.title("Distribution of Vehicle's Age: Starting 2022", weight=1000,size=20);

# %% [markdown]
# ## Driver's Sex
# The variable of interest here is categorical with two levels thus a catplot is appropriate to visualize the counts. Males represented 62% of the population and were engaged in a crash 24% more than females. The data was collected in 2020 during COVID times so we speculate if the distribution is a consequence of less female drivers on the road as caretakers during mandatory school closure.

# %%
plot_sorted_level_counts(dataframe=eda_df, 
                         plotting_column="sex_imname", 
                         title="Proportion of Driver's Sex", 
                         title_fontsize=20, 
                         xlab_fontsize=20,
                         ylab_fontsize=20,
                         xlabel="Sex", 
                         ylabel="Count",
                         figsize=(18, 7), 
                         title_weight=None, 
                         round_digits=3);

# %% [markdown]
# ## Traffic Way
# The variable of interest here is categorical with 7 levels thus a catplot is appropriate to visualize the counts and relative proportions. Almost 51% of accidents occurred on two-way traffic flow without a divider and drastically decreases by over 50% with a median present. This conforms to our general understanding that presence of a divider of any kind reduces collisions .

# %%
## Data clean VTRAFWAYNAME
# Remove "Reported as Unknown" and "Not Reported"
traffic = pd.DataFrame(eda_df)
traffic = traffic.loc[(traffic['vtrafwayname'] != 'Reported as Unknown') & (traffic['vtrafwayname'] != 'Not Reported')]

# %%
plot_sorted_level_counts(dataframe=traffic, 
                         plotting_column="vtrafwayname", 
                         title="Proportion of Traffic Flow", 
                         xlabel="Traffic Flow", 
                         ylabel="Count",                          
                         title_fontsize=20, 
                         xlab_fontsize=20,
                         ylab_fontsize=20, 
                         title_weight=None,
                         figsize=(18, 7), 
                         round_digits=3)

# %% [markdown]
# ## Time of Day
# The variable of interest here was originally numerical however we binned the 24 hour in a day to make it categorical with four levels thus a catplot is appropriate to visualize the counts. Morning (6am-noon) accounted for 26% of the data, afternoon (noon-6pm) 27%, evening (6pm-midnight) 33%, and night (midnight-6am) 14%. We were a bit surprised to see morning and afternoon have lower distributions than evening when it coincided with hours that people typically drive to/from work. Then again, this was during 2020 COVID so there could have been less people on the road during these times due to work-from-home.

# %%
sns.catplot(data = eda_df,
            x='hour_binned', 
            kind="count", 
            order=['Morning','Afternoon','Evening', 'Night'], 
            height=5, 
            aspect=3, 
            palette='husl').set_xticklabels(rotation=40).set_yticklabels(rotation=40);

plt.xlabel('Time of Day', size=20, weight=1000)
plt.ylabel('Count', size=20, weight=1000)
plt.title("Proportion of Time of Day", size=20);

# %% [markdown]
# # Explore Joint Attributes
# Visualize relationships between attributes: Look at the attributes via scatter plots, correlation, cross-tabulation, group-wise averages, etc. as appropriate. Explain any interesting relationships.

# %% [markdown]
# ## Pairwise plot of continuous variables
# ### Driver's age, vehicle's age, traveling speed, speed limit
# Given that the features of interest are continuous, a pair grid plot is appropriate to visualize individual distribution and its relationship with each other. The off-diagonal plots are histograms of each feature displaying evident right skewed behavior between ages of driver/vehicle and traveling speed. This observation tracks with our intuition because we expect drivers to be on the younger end with relatively newer cars driving well below the typical highway speed, as most accidents occur on local roads. The top half of the pair grid plot depicts a scatterplot between all the features. A noteworthy consideration is traveling speed decreases with both driver and vehicle age to indicate that older drivers do not drive as fast and older cars are perhaps not capable of mainting high speed. However, this could be attributed to fewer observations in that range. Traveling speed is more prevalent at the upper end of speed limit but we doubt its significance. The bottom half of the pair grid plot is a bivariate kde plot. Heavier density is on the lower/younger end of driver age, vehicle age, and traveling speed which is consistent with our previous acknowledgement but we'll concede sample size is potentially smaller at the opposite end. We will consider logging these features for modeling.

# %%
g = sns.PairGrid(quant_var, diag_sharey=False);
g.map_upper(sns.scatterplot);
g.map_lower(sns.kdeplot);
g.map_diag(sns.kdeplot);
# adapted code from https://seaborn.pydata.org/generated/seaborn.PairGrid.html

# %% [markdown]
# ## Sex vs. alcohol impairment
# This relationship is comparing two binary variables: Male,Female and Alcohol Involved, No Alcohol Involved and their distribution.
#
# Very quickly we can see that the driver in most accidents recorded was not impaired by alcohol regardless of gender (44650 vs 3577 cases), but how does this break down by gender? Visually, we can tell from the bar graphs of counts that males make up most of the accidents, but whether there is a difference between the Alcohol groups is difficult to tell from this graph.  To get better insight on how alcohol and gender interact, the counts were normalized.  It is seen that there is about a 9% (61.1% to 70.4%) increase in accidents involving males when alcohol is involved vs when it is not. We will explore later how this could possibly relate to accident severity.

# %%
##straight counts
ct = pd.crosstab([ df['alchl_imname']], 
                       df['sex_imname'] 
                      )
mapl=sns.color_palette('husl')
fig,ax = plt.subplots()
ct.plot(kind='barh',stacked=True,color=mapl,ax=ax)


for y in [0,1]:
    ax.text(1+30000, y, 'Total = '+str(ct.iat[y,0]+ct.iat[y,1]),weight='bold')
    
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel("Count",weight="bold")
plt.ylabel("Alcohol Involvment",weight="bold")
plt.title('Alcohol vs Gender',weight='bold')
plt.show()

# %%
##normalized
ct = pd.crosstab([ df['alchl_imname']], 
                       df['sex_imname'] ,
                      normalize="index")

fig,ax = plt.subplots()
ct.plot(kind='barh',stacked=True,color=mapl,ax=ax)

for y in [0,1]:
    for x in [0,1]:
        if x==0:
            ax.text(x+.1, y, str(round(100*ct.iat[y,x],1))+'%',weight='bold')
        else:
            ax.text(x-.3, y, str(round(100*ct.iat[y,x],1))+'%',weight='bold')


plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel("Proportion",weight="bold")
plt.ylabel("Alcohol Involvment",weight="bold")
plt.title('Alcohol vs Gender',weight='bold')
plt.show()

# %% [markdown]
# ## Day of week vs. alcohol impairment

# %% [markdown]
# Key Insight:
#
# For Monday-Thursday, only 5%-6% of all collisions involved an intoxicated driver. This percentage see's a
# slight bump to nearly 7% on Friday, and then increases even further to 10.9% and 11.96% on Saturday and Sunday, respectively.
# This insight aligns with our intuitions on human behavior, that on weekends people tend to break their normal routine
# and may be more likely to engage in activities that involve alcohol consumption.

# %%
plot_feature_counts_by_grouping_level(dataframe=df, 
                                      plotting_column="alchl_imname", 
                                      grouping_column="wkdy_imname", 
                                      num_rows=4, 
                                      num_cols=2, 
                                      figsize=(18, 20), 
                                      title_fontsize=12,
                                      round_digits=2, 
                                      tick_rotation=45)
# This plot shows the distribution of alcohol related vs non-alcohol related crashes, broken down
# by the day of the week. Note that the total number of observations used in each subplot is available 
# in the plots title, and the percentage of observations in each level of the alcohol feature is annotated above the bar.

# %% [markdown]
# ## Age vs Time of Day

# %% [markdown]
# Key Insight Strip Plot:
#
# 1. The fact that the cluster of observations in the "Night" subgroup is noticably shorter than
# the cluster for any other period of the day is evidence that suggests drivers who get into collisions
# a night are less likely to be among the oldest members of the population.
#
# 2. The larger proportion of blue dots in the night subgroup, and the prominent cluster of blue near the
# lower section of the night subgroup, indicate that collisions that occur at night are more likely
# to involve speeding, particularly when the driver is approximately 30 years old or younger.
#
# Key Insight Point Plot:
#
# This plot helps us start to quantify some of the intuitions we gained by viewing the plot above.
#
# 1. Our best estimate for the mean age of drivers who are involved in a night time
# collision while speeding is approximately 31 years old. Our best estimate for the
# age of a driver who is involved in a night time collision while they were not
# speeding is approximately 35 years old.
#
# 2. For all periods of the day, the average age of a driver who is involved in a speeding
# collisions is significantly less than a driver who is involved in a non-speeding related
# collision. Additionally, the estimated difference in mean ages appears to be relatively
# consistent across the periods of the day.

# %%
plot_title = ("Distribution of Age for different periods of the day\n"
              f"Only considers crashes where speeding status is known ({df.loc[df['speeding_status']!='unknown',:].shape[0]} out of {df.shape[0]} crashes)")

create_strip_plot(dataframe=df.loc[df["speeding_status"]!="unknown",:], 
                  categorical_feature="hour_binned", 
                  continuous_feature="age_im", 
                  shading_feature="speeding_status", 
                  title_fontsize=18,
                  title=plot_title,
                  jitter=0.25, 
                  alpha=0.7);

# %%
create_point_plot(dataframe=df, 
                  categorical_feature="hour_binned", 
                  continuous_feature="age_im", 
                  shading_feature="speeding_status");

# %% [markdown]
# ## Age of Vehicle vs Rural/Urban
# The rural and urban divide is a contentious modern-day struggle that plays out even in the amount and age of cars in an accident.  The driving landscapes of these areas are vastly different which is why this has been chosen as an important feature to represent.
#
# The counts of urban and rural area car accidents in our dataset are in a ratio of 3:1 as can be visualized in the stacked kernel density graph. The assumption here is the density of cars in an urban vs rural area is greater which could lead to more accidents.
#
# The normalized kernel density graph tells a different story.  The proportion of cars in accidents in rural vs urban areas increases as the age of the car increases.  Having knowledge of living in both an urban and rural environment, this does fit with our intuition of, 'rural areas have older cars'.  Whether this is actually true is hard to say, yet the difference in the plots still remains interesting.

# %%
##Age of Car
mapl=sns.color_palette('husl')

fig,ax = plt.subplots()

temp=df[df.mod_yearname!="Not Reported"]
temp=temp[temp.mod_yearname!="Unknown"]
temp=temp[temp.mod_yearname.astype(np.int64)>1979]
temp.mod_yearname.astype(np.int64)

sns.kdeplot(abs(temp.mod_yearname.astype(np.int64)-2022),shade=True,hue=temp["urbanicityname"],
            palette=mapl[3:5],multiple="fill").set_xlabel("Age of Car: 2022 Starting Year")
plt.title("Proportional Density: Age of Car by Rural/Urban")
ax.get_legend().set_title(None)

plt.show()

# %%
fig,ax = plt.subplots()
sns.kdeplot(abs(temp.mod_yearname.astype(np.int64)-2022),shade=True,hue=temp["urbanicityname"],
            palette=mapl[3:5],multiple="stack").set_xlabel("Age of Car: 2022 Starting Year")
ax.get_legend().set_title(None)
plt.title("Age of Car Density by Rural/Urban")
plt.show()

# %% [markdown]
# # Explore Attributes and Class
# Identify and explain interesting relationships between features and the class you are trying to predict (i.e., relationships with variables and the target classification).

# %% [markdown]
# ## Severity vs. Gender and Alcohol Impairment
# Building on the discussion on gender and alcohol involvement earlier, we decided to see if there is any effect from this interaction on the accident severity.  When the variables are factored out, from the bar graph of counts we can again see that males make up most accidents regardless of alcohol being involved or not.
#
# Using the same process as before, we normalized the counts to get a better idea of their distribution.  The proportional graph tells us that when alcohol is involved, there is a noticeable increase in fatal injury and suspected series injury regardless of gender.  We also can see that males have a larger proportion of these two injury categories regardless of whether alcohol is involved or not. The level distributions are different enough that this will be a strong candidate for the model building stage.

# %%
##GENDER ALCOHOL AND SEVERITY
##straight counts
ct = pd.crosstab([df['alchl_imname'],
                  df['sex_imname']],
                 df['maxsev_imname'] 
                      )

mapl=sns.color_palette('husl')
fig,ax = plt.subplots()
ct.plot(kind='barh',stacked=True,color=mapl,ax=ax)


for y in range(4):
    ax.text(1+30000, y, 'Total = '+str(ct.iat[y,0]+ct.iat[y,1]),weight='bold')
    


plt.legend(bbox_to_anchor=(.45, .3), loc=2, borderaxespad=0.)
plt.xlabel("Count",weight="bold")
plt.ylabel("")
plt.title('Alcohol,Gender and Accident Severity Cross Tabulation Counts',weight='bold')
plt.show()

# %%
##normalized
ct = pd.crosstab([df['alchl_imname'],
                  df['sex_imname']], 
                 df['maxsev_imname'] , 
                      normalize="index")

fig,ax = plt.subplots()
ct.plot(kind='barh',stacked=True,color=mapl,ax=ax)


for y in range(4):
    
    for x in range(4):
        if x==0:
            ax.text(.001, y, str(round(100*ct.iat[y,x],1))+'%',weight='bold')
        elif x==1:
            ax.text(.2, y, str(round(100*ct.iat[y,x],1))+'%',weight='bold')
        elif x==2:
            ax.text(.55, y, str(round(100*ct.iat[y,x],1))+'%',weight='bold')
        elif x==3:
            ax.text(.9, y, str(round(100*ct.iat[y,x],1))+'%',weight='bold')


plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel("Proportion",weight="bold")
plt.ylabel("")
plt.title('Alcohol,Gender and Accident Severity Cross Tabulation Proportions',weight='bold')
plt.show()

# %% [markdown]
# ## Severity vs. Time of Day

# %% [markdown]
# This plot shows the distribution of accident severity, and is broken down
# by which period of the day the accident occured during (Morning, Afternoon, Evening, or Night).
#
# Key Insight:
#
#
# We see that the percentage of accidents that result in fatality is noticably higher
# for collisions that occur at night, vs any other period of the day. This result is intuitive
# because there are a number of factors we believe to be more common at night that contribute to
# making a collision more severe. These factors include:
#
# 1. Increased Alcohol consumption at night
# 2. Increased driver fatigue at night
# 3. Decreased visibility at night

# %%
plot_feature_counts_by_grouping_level(dataframe=df, 
                                      plotting_column="maxsev_imname", 
                                      grouping_column="hour_binned", 
                                      num_rows=2, 
                                      num_cols=2, 
                                      figsize=(18, 10), 
                                      title_fontsize=13,
                                      round_digits=2)

# %% [markdown]
# ## Severity vs. Age of Driver

# %% [markdown]
# Key Insights Strip Plot:
#
# 1. For the lower severity crashes (left half of plot), the blue gets drowned out by the orange, which
#    shows that there are many more non-speeding related collisions than ones that did involve speeding.
#
# 2. For the higher severity crashes (right half of plot), we start seeing a lot more blue coming through,
#    indicating that speeding may be a larger factor in high severity collisions. This insight aligns with our
#    intuition that at increased speeds a collision is likely to be more dangerous.
#
# 3. Notice the larger clusters of blue on the lower half, indicating that younger drivers seem to speed more.
#    This also aligns with general intuition about human behavior and maturity/responsibility to follow traffic laws.
#
# Need to acknowledge that in most cases, speeding is actually "unknown". Those points have been removed for this chart, but
# if they are included, everything gets drowned out by the "unknown" speeding observations
#
# Key Insights Point Plot:
#
#
# 1. For the lower severity crashes (left half of plot), the blue gets drowned out by the orange, which
#    shows that there are many more non-speeding related collisions than ones that did involve speeding.
#
# 2. For the higher severity crashes (right half of plot), we start seeing a lot more blue coming through,
#    indicating that speeding may be a larger factor in high severity collisions. This insight aligns with our
#    intuition that at increased speeds a collision is likely to be more dangerous.
#
# 3. Notice the larger clusters of blue on the lower half, indicating that younger drivers seem to speed more.
#    This also aligns with general intuition about human behavior and maturity/responsibility to follow traffic laws.
#
# Need to acknowledge that in most cases, speeding is actually "unknown". Those points have been removed for this chart, but
# if they are included, everything gets drowned out by the "unknown" speeding observations

# %%
plot_title = ("Distribution of Age for each level of crash severity\n"
              f"Only considers crashes where speeding status is known ({df.loc[df['speeding_status']!='unknown',:].shape[0]} out of {df.shape[0]} crashes)")

create_strip_plot(dataframe=df.loc[df["speeding_status"]!="unknown",:], 
                  categorical_feature="maxsev_imname", 
                  continuous_feature="age_im", 
                  shading_feature="speeding_status", 
                  title=plot_title,
                  jitter=0.25, 
                  alpha=0.5);

# %%
create_point_plot(dataframe=df, 
                  categorical_feature="maxsev_imname", 
                  continuous_feature="age_im", 
                  shading_feature="speeding_status");

# %% [markdown]
# ## Severity vs. Area

# %% [markdown]
# Key Insights:
#
# 1. As shown in the title of the plots, this is a nice visual reminder that our dataset includes
#    nearly 3 times as many collisions from urban areas as compared to rural. The Crash Report
#    Sampling System Analytics manual associated with this dataset describes in detail the careful
#    sampling techniques that were used when collecting this collision dataset. This is an interesting
#    point because their it lends some credibility to the idea that this 3x discrepancy may reflect
#    the underlying distribution of all collisions.
#
# 2. Although the difference is relatively minor, it is worth noting that the most common
#    accident severity in rural areas is no apparent injury, while for urban areas, the most
#    common is possible injury. It will be interesting to see if these subtle differences are
#    enough for our machine learning algorithms to pick up on, and utilize towards effectively
#    separating the classes.

# %%
plot_feature_counts_by_grouping_level(dataframe=df, 
                                      plotting_column="maxsev_imname", 
                                      grouping_column="urbanicityname", 
                                      num_rows=1, 
                                      num_cols=2, 
                                      figsize=(18, 7), 
                                      title_fontsize=16,
                                      round_digits=2)

# %% [markdown]
# # New Features
# Are there other features that could be added to the data or created from existing features? Which ones?
#
# 1. Incorporated new feature `hour_binned` that encompassed time of accident into four levels: morning, afternoon, evening, night
# 2. Incorporated new feature `mod_age` that calculated vehicle's age
# 3. Incorporated new feature `speeding_status` that noted if driver went over the speed limit, under the limit, or speed unknown
# 4. Should expand `speeding_status` feature with actual values e.g., +5 or -5 for 5 mph over/under, respectively
# 5. Potentially useful feature: historical proportion of car make or model that have propensity of being in accidents
# 6. Potentially useful feature: lane size as research has shown increasing lane size is associated with a decrease in accident rates
# 7. Potentially useful feature: vehicle role e.g., presence of 18 wheelers is associated with an increase in accident but this rate decreases when they are allowed their own lane

# %% [markdown]
# # Exceptional Work
# You have free reign to provide additional analyses. One idea: implement dimensionality reduction, then visualize and interpret the results.

# %% [markdown]
# The section below creates an interactive Bokeh heatmap that has the following features:
#
# 1. A grid is created using the levels of two categorical variables. Each cell corresponds to the set of
#    observations that exist with that combination of levels for the two categorical features.
#
# 2. A drop down menu is provided to select how the cells should be shaded. Current options are to shade
#    by the percentage of the first categorical variable (column percent) or by percentage of the second
#    categorical variable (row percent).
#
# 3. A second dropdown menu is provided to change what the second categorical variable should be. Changing this
#    menu updates the vertical axis of the heatmap with the factor levels for the newly selected feature.
#
# 4. A hover tool is provided, which allows you to hover over the heatmap cells and view summary statistics on the
#    observations contained within the cell. Summary statistics include count of observations, row percent, column
#    percent, and central tendency parameters (mean, median) for other continuous features in the dataset.
#
# 5. Functionality is provided to dynamically update plot title, labels, shading menu options, and
#    hover tool statistics as the menu selections change.

# %%
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.transform import factor_cmap
from bokeh.layouts import column, row
from bokeh.models import (BasicTicker, ColorBar, ColumnDataSource, HoverTool, Select, CustomJS, Title,
                          LinearColorMapper, PrintfTickFormatter)

from bokeh.palettes import mpl
from bokeh.transform import transform

from pandas.api.types import CategoricalDtype

# %%
def create_group_percentages_df(df, group_feature, subgroup_feature, agg_column_name):
    
    dataframe = pd.DataFrame(df.groupby(by=[group_feature])[subgroup_feature].value_counts(normalize=True)).rename(columns={subgroup_feature:agg_column_name})
    
    return dataframe


def create_aggregate_df(df, categorical_feature1, categorical_feature2, continuous_feature, cat_feat1_name, 
                        cat_feat2_name, continuous_feat_name, aggregate_functions=['mean', 'median', 'count'], 
                        include_zero_observation_categories=True, custom_sort=True, 
                        custom_sort_order=['No Apparent Injury', 'Possible Injury', 'Suspected Serious Injury', 'Fatal Injury']):
    
    pct_column1_name = f"pct_of_{cat_feat1_name}_class"
    pct_column2_name= f"pct_of_{cat_feat2_name}_class"
    
    pct_df1 = create_group_percentages_df(df=df,
                                          group_feature=categorical_feature1, 
                                          subgroup_feature=categorical_feature2, 
                                          agg_column_name=pct_column1_name)
    
    # Turn decimal percentage (between 0 and 1) into percentage between 0 and 100
    pct_df1[pct_column1_name] = pct_df1[pct_column1_name] * 100
    
    pct_df2 = create_group_percentages_df(df=df,
                                          group_feature=categorical_feature2, 
                                          subgroup_feature=categorical_feature1, 
                                          agg_column_name=pct_column2_name).swaplevel()
    
    # Turn decimal percentage (between 0 and 1) into percentage between 0 and 100
    pct_df2[pct_column2_name] = pct_df2[pct_column2_name] * 100
    
    
    agg_functions = [(f"{func}_age", func) if func != 'count' else (f"total_observations", func) for func in aggregate_functions]
    agg_df = df.groupby(by=[categorical_feature1, categorical_feature2])[continuous_feature].agg(agg_functions)
    
    pct_df1 = pct_df1.join(other=pct_df2, on=[categorical_feature1, categorical_feature2])
    agg_df = agg_df.join(other=pct_df1, on=[categorical_feature1, categorical_feature2])
    
    agg_df = agg_df.reset_index()
    
    if include_zero_observation_categories:
        list1 = agg_df[categorical_feature1].tolist()
        list2 = agg_df[categorical_feature2].tolist()
        
        unique1 = df[categorical_feature1].unique().tolist()
        unique2 = df[categorical_feature2].unique().tolist()
        unique_combos = [(one, two) for one in unique1 for two in unique2]
        present_combos = [(one, two) for one, two in zip(list1, list2)]
        missing_combos = [combo for combo in unique_combos if combo not in present_combos]
        
        categorical_columns = [categorical_feature1, categorical_feature2]
        zero_columns = [column for column in agg_df.columns if column not in categorical_columns]
        zero_dict = {column:[0 for _ in range(len(missing_combos))] for column in zero_columns}
        
        zero_dict[categorical_feature1] = [feat1 for feat1, feat2 in missing_combos]
        zero_dict[categorical_feature2] = [feat2 for feat1, feat2 in missing_combos]
        zero_df = pd.DataFrame(zero_dict)
        
        agg_df = pd.concat(objs=[agg_df, zero_df], axis='index')
        
        if not custom_sort:
            agg_df.sort_values(by=categorical_feature1, inplace=True)
            
    if custom_sort:
        category = CategoricalDtype(custom_sort_order, ordered=True)
        agg_df[categorical_feature1] = agg_df[categorical_feature1].astype(category)
        agg_df.sort_values(by=categorical_feature1, inplace=True)
        
        
    return agg_df

# %%
example_ag_df = create_aggregate_df(df=df,
                            categorical_feature1="maxsev_imname", 
                            categorical_feature2="alchl_imname", 
                            continuous_feature="age_im", 
                            cat_feat1_name="severity", 
                            cat_feat2_name="alch", 
                            continuous_feat_name="age", 
                            include_zero_observation_categories=True)

example_ag_df
# Out:
#               maxsev_imname         alchl_imname   mean_age  median_age  \
# 2        No Apparent Injury     Alcohol Involved  37.932099        35.0
# 3        No Apparent Injury  No Alcohol Involved  39.612975        36.0
# 4           Possible Injury     Alcohol Involved  38.430389        35.0
# 5           Possible Injury  No Alcohol Involved  40.042567        36.0
# 6  Suspected Serious Injury     Alcohol Involved  36.228602        33.0
# 7  Suspected Serious Injury  No Alcohol Involved  39.124317        35.0
# 0              Fatal Injury     Alcohol Involved  38.011561        33.0
# 1              Fatal Injury  No Alcohol Involved  41.886458        38.0
#
#    total_observations  pct_of_severity_class  pct_of_alch_class
# 2               972.0               4.582528          27.173609
# 3             20239.0              95.417472          45.328108
# 4              1336.0               6.731157          37.349734
# 5             18512.0              93.268843          41.460246
# 6               923.0              15.745479          25.803746
# 7              4939.0              84.254521          11.061590
# 0               346.0              26.493109           9.672910
# 1               960.0              73.506891           2.150056

# %%
def get_plot_info(categorical_feature1, categorical_feature2, cat_feat1_name, cat_feat2_name, shade_categorical1_pct):
    
    plot_info = {}
    
    if shade_categorical1_pct:
        shade_column = f"pct_of_{cat_feat1_name}_class"
        shade_column_option2 = f"pct_of_{cat_feat2_name}_class"
        
        plot_info["shade_column"] = shade_column
        plot_info["shade_column_option2"] = shade_column_option2
        
        plot_info["MAIN_TITLE"] = f"Heatmap showing percentage breakdown of {categorical_feature2} within each level of {categorical_feature1} (shading by column percent)"
        plot_info["SUBTITLE"] = f"{shade_column}=column percent,   {shade_column_option2}=row percent"
        
        plot_info["MAIN_TITLE_OPTION2"] = f"Heatmap showing percentage breakdown of {categorical_feature1} within each level of {categorical_feature2} (shading by row percent)"
        plot_info["SUBTITLE_OPTION2"] = f"{shade_column_option2}=row percent,   {shade_column}=column percent"
    else:
        shade_column = f"pct_of_{cat_feat2_name}_class"
        shade_column_option2 = f"pct_of_{cat_feat1_name}_class"
        
        plot_info["shade_column"] = shade_column
        plot_info["shade_column_option2"] = shade_column_option2
        
        plot_info["MAIN_TITLE"] = f"Heatmap showing percentage breakdown of {categorical_feature1} within each level of {categorical_feature2} (shading by row percent)"
        plot_info["SUBTITLE"] = f"{shade_column}=row percent,   {shade_column_option2}=column percent"
        
        plot_info["MAIN_TITLE_OPTION2"] = f"Heatmap showing percentage breakdown of {categorical_feature2} within each level of {categorical_feature1} (shading by column percent)"
        plot_info["SUBTITLE_OPTION2"] = f"{shade_column_option2}=column percent,   {shade_column}=row percent"
        
        
    return plot_info

def get_all_plot_infos(categorical_feature1, categorical_feature2, cat_feat1_name, cat_feat2_name, shade_categorical1_pct):
    
    p_info = {cat_feature2:get_plot_info(categorical_feature1=categorical_feature1, 
                                         categorical_feature2=cat_feature2, 
                                         cat_feat1_name=cat_feat1_name, 
                                         cat_feat2_name=cat_feature2_name, 
                                         shade_categorical1_pct=shade_categorical1_pct) for cat_feature2, cat_feature2_name in zip(categorical_feature2, 
                                                                                                                                   cat_feat2_name)}
    
    
    return p_info


def get_all_aggregate_dfs(df, categorical_feature1, categorical_feature2, continuous_feature, cat_feat1_name, 
                        cat_feat2_name, continuous_feat_name, aggregate_functions=['mean', 'median', 'count']):
    
    agg_data = {cat_feature2:create_aggregate_df(df=df,
                                                 categorical_feature1=categorical_feature1, 
                                       categorical_feature2=cat_feature2, 
                                       continuous_feature=continuous_feature, 
                                       cat_feat1_name=cat_feat1_name, 
                                       cat_feat2_name=cat_feature2_name, 
                                       continuous_feat_name=continuous_feat_name) for cat_feature2, cat_feature2_name in zip(categorical_feature2, 
                                                                                                                                   cat_feat2_name)}
    

    
    return agg_data


def get_all_tool_tips(agg_dataframes, categorical_feature1):
    
    tools = {}
    
    for feature, ag_df in agg_dataframes.items():
        
        axes_columns = [categorical_feature1, feature]
        
        # List the columns that contain data we want to main availble to the hover tool
        tools[feature] = [(f"{column_name}", f"@{column_name}") for column_name in ag_df.columns 
                          if column_name not in axes_columns]

    return tools

# %%
def create_bokeh_heatmap(dataframe, categorical_feature1="maxsev_imname", 
                         categorical_feature2=["speeding_status", "sex_imname", "weathername", "alchl_imname", "wkdy_imname", "hour_binned", "lgtcon_imname"], 
                         cat_feat2_name=["speeding", "sex","weather","alcohol", "weekday", "hour", "light"],
                         aggregate_functions=['mean', 'median', 'count'], colors=None, palette_name="Plasma", palette_num=11,
                         continuous_feature="age_im", cat_feat1_name="severity", continuous_feat_name="age", fig_width=1200, fig_height=500, 
                         shade_categorical1_pct=True, tools="hover", x_axis_location="above", color_bar_tick_format="%.2f%%", 
                         color_bar_location='right', subtitle_font_style="italic", title_font_size="12pt"):
    
    
    start_cat2 = categorical_feature2[0]
    start_cat2_name = cat_feat2_name[0]
    
    # Plot labels need to be update when:
    # 1) The column used to shade the heatmap changes
    # 2) The column used on the heatmap vertical axis changes.
    # p_infos contains all the title and subtitle options associated with the 
    # available menu choices. These are used to update the plot title in 
    # the javascript callback. 
    p_infos = get_all_plot_infos(categorical_feature1=categorical_feature1, 
                                 categorical_feature2=categorical_feature2, 
                                 cat_feat1_name=cat_feat1_name, 
                                 cat_feat2_name=cat_feat2_name, 
                                 shade_categorical1_pct=shade_categorical1_pct)
        
    # Calculate the aggregation statistics. This is the information Bokeh will use to both
    # color the heatmap, and present additional statistics via the hover tool
    agg_dfs =  get_all_aggregate_dfs(df=dataframe,
                                     categorical_feature1=categorical_feature1, 
                                     categorical_feature2=categorical_feature2, 
                                     continuous_feature=continuous_feature, 
                                     cat_feat1_name=cat_feat1_name, 
                                     cat_feat2_name=cat_feat2_name, 
                                     continuous_feat_name=continuous_feat_name, 
                                     aggregate_functions=aggregate_functions)
    
    # When we update the column name, we want the hover tool to get more information, which means
    # we need a new set of tooltips. This creates the required tool tips for all menu options.
    all_tool_tips = get_all_tool_tips(agg_dataframes=agg_dfs, categorical_feature1=categorical_feature1)
    
    # Initial hover-tool information and initial dataframe.
    tool_tip_list = all_tool_tips[start_cat2]
    aggregate_df = agg_dfs[start_cat2]

    # Output in the jupyter notebook
    output_notebook()
    
    # Set the color palette, either a list passed by the user,
    # or default to bokehs version of matplotlib Plasma 11.
    if colors is None:
        colors = mpl[palette_name][palette_num]
    
    # Color mapper shading based on percentages 
    mapper = LinearColorMapper(palette=colors, low=aggregate_df[p_infos[start_cat2]['shade_column']].min(), 
                               high=aggregate_df[p_infos[start_cat2]['shade_column']].max())
    
    
    # Set up the figure
    p = figure(width=fig_width, 
               height=fig_height, 
               x_range=aggregate_df[categorical_feature1].unique().tolist(), 
               y_range=aggregate_df[start_cat2].unique().tolist(),
               toolbar_location=None, 
               x_axis_location=x_axis_location)
    
    # Instantiate title and subtitle objects, and add to chart
    subtitle_renderer = Title(text=p_infos[start_cat2]["SUBTITLE"], text_font_style=subtitle_font_style)
    title_renderer = Title(text=p_infos[start_cat2]["MAIN_TITLE"],  text_font_size=title_font_size)
    p.add_layout(subtitle_renderer, place='above')
    p.add_layout(title_renderer, place='above')
    
    # Set up the data source
    source = ColumnDataSource(aggregate_df)
    agg_dfs = {key:value.to_dict(orient='list') for key, value in agg_dfs.items()}
    
    # Color in the squares
    renderer  = p.rect(x=categorical_feature1, 
                       y=start_cat2, 
                       width=1, 
                       height=1, 
                       source=source,
                       fill_color={'field': p_infos[start_cat2]["shade_column"], 'transform': mapper})
    
    # Instantiate Hover Tool and add to chart
    hover_tool = HoverTool(renderers=[renderer], tooltips=tool_tip_list)
    p.add_tools(hover_tool)
                                
    # Create a color bar
    color_bar = ColorBar(color_mapper=mapper,
                         ticker=BasicTicker(desired_num_ticks=len(colors)),
                         formatter=PrintfTickFormatter(format=color_bar_tick_format))
    
    # Put the color bar on the right hand side
    p.add_layout(color_bar, color_bar_location)
    
    # Axis Settings
    p.axis.axis_line_color = None
    p.axis.major_tick_line_color = None
    p.axis.major_label_text_font_size = "8pt"
    p.axis.major_label_standoff = 0
    p.xaxis.major_label_orientation = 1.0
    
    # Set up the drop down ticker
    DEFAULT_TICKERS = [p_infos[start_cat2]["shade_column"], p_infos[start_cat2]["shade_column_option2"]]
    ticker = Select(value=p_infos[start_cat2]["shade_column"], options=DEFAULT_TICKERS)
    
    column_choices = categorical_feature2
    column_ticker = Select(value=start_cat2, options=column_choices)

    # Write the javascript callback that gets triggered when the dropdown menu changes
    # This callback will update the plot title and plot shading based on what is selected in the drop down.
    ticker_change = CustomJS(args = dict(renderer = renderer, 
                                         p = p, 
                                         subtitle_renderer=subtitle_renderer, 
                                         title_renderer=title_renderer,
                                         p_titles=p_infos),
                             code="""
    
    const title_key = current_column.value;
    
    const active = cb_obj.value;
    
    const data = renderer.data_source.data[active];
    const {transform} = renderer.glyph.fill_color;
    transform.low = Math.min(...data);
    transform.high = Math.max(...data);
    renderer.glyph.fill_color = {field: cb_obj.value, transform: transform};
    
    
    const subkey = "SUBTITLE";
    const subkey2 = "SUBTITLE_OPTION2";
    const mainkey = "MAIN_TITLE";
    const mainkey2 = "MAIN_TITLE_OPTION2";
    const shadekey = "shade_column";
    
    const subtitle = p_titles[title_key][subkey];
    const maintitle = p_titles[title_key][mainkey];
    const maintitle_option2 = p_titles[title_key][mainkey2];
    const subtitle_option2 = p_titles[title_key][subkey2];
    const shade_option1 = p_titles[title_key][shadekey];
    
    if(active === shade_option1){
        subtitle_renderer.text = subtitle;
        title_renderer.text= maintitle;
    }else{
        title_renderer.text = maintitle_option2;
        subtitle_renderer.text = subtitle_option2;
    }
    
    p.reset.emit()
                                          """)
    
        # Write the javascript callback that gets triggered when the dropdown menu changes
    # This callback will update the plot title and plot shading based on what is selected in the drop down.
    column_ticker_change = CustomJS(args = dict(renderer = renderer, 
                                                p = p, 
                                                subtitle_renderer=subtitle_renderer, 
                                                title_renderer=title_renderer, 
                                                all_datasets=agg_dfs,
                                                source=source, 
                                                hover_tool=hover_tool,
                                                all_tool_tips=all_tool_tips,
                                                p_titles=p_infos),
                             code="""
    
    
    const subkey = "SUBTITLE";
    const subkey2 = "SUBTITLE_OPTION2";
    const mainkey = "MAIN_TITLE";
    const mainkey2 = "MAIN_TITLE_OPTION2";
    const shadekey = "shade_column";
    const shadekey2 = "shade_column_option2";
        
    const current_shade_column = current_shade.value;
    const new_column_name = cb_obj.value;
    
    const subtitle = p_titles[new_column_name][subkey];
    const maintitle = p_titles[new_column_name][mainkey];
    const maintitle_option2 = p_titles[new_column_name][mainkey2];
    const subtitle_option2 = p_titles[new_column_name][subkey2];
    
    const new_shade_column = p_titles[new_column_name][shadekey];
    const new_shade_option2 = p_titles[new_column_name][shadekey2];
    const new_shade_options = [new_shade_column, new_shade_option2];
    
    current_shade.value = new_shade_column;
    current_shade.options = new_shade_options;
    
    subtitle_renderer.text = subtitle;
    title_renderer.text= maintitle;
    
    hover_tool.tooltips = all_tool_tips[new_column_name];
    const new_data = all_datasets[new_column_name];
    
    renderer.glyph.y.field=new_column_name;
    renderer.data_source.data['y'] = new_data[new_column_name];
    renderer.data_source.data = new_data;

    const data = renderer.data_source.data[new_shade_column];
    const new_labels = [...new Set(renderer.data_source.data[new_column_name])];

    p.y_range.factors = new_labels;
    p.y_range.end = new_labels.length;
    
    const {transform} = renderer.glyph.fill_color;
    transform.low = Math.min(...data);
    transform.high = Math.max(...data);
    renderer.glyph.fill_color = {field: new_shade_column, transform: transform};
    
    p.reset.emit()
                                          """)
    
    
    # Set up ticker callbacks
    ticker.js_on_change('value', ticker_change)
    column_ticker.js_on_change('value', column_ticker_change)
    
    # Let the ticker callbacks talk to eachother
    ticker_change.args["current_column"] = column_ticker
    column_ticker_change.args["current_shade"] = ticker
    
    # Row of tickers
    ticker_row = row(children=[ticker, column_ticker])
    
    # Put the plot and both tickers in a layout
    layout = column(children=[ticker_row, p], sizing_mode="scale_width")
    
    #return show(p)
    return show(layout)

# %%
create_bokeh_heatmap(dataframe=df)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="55e0ec86-4097-4871-a520-43c3f2f76c2a" data-root-id="1051"></div>

# %% [markdown]
# # References
# Data dictionary referenced from [CRSS Analytical Users Manual](https://crashstats.nhtsa.dot.gov/Api/Public/ViewPublication/813236)
